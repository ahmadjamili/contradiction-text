# %% [markdown]
# ### importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import nltk

# %% [markdown]
# ### loading dataset

# %%
dataset=pd.read_csv('C://Users//ahmad//OneDrive//Desktop//New folder (2)/train.csv')

# %%
dataset
# Out:
#                                              SENTENCE A
# 0                         someone is dirtying an animal  \
# 1     a woman in a black dress is pulling a cart and...
# 2     a person is cutting garlic into pieces with a ...
# 3     a woman is rock climbing pausing and calculati...
# 4                 a rabbit is playing with a toy rabbit
# ...                                                 ...
# 6689     there is no woman standing near three children
# 6690  the man is standing on a rocky mountain and gr...
# 6691                    a woman is putting on eyeshadow
# 6692  five wooden stands are in front of each childs...
# 6693                there is no man dancing on the road
#
#                                              SENTENCE B  label
# 0                          a woman is cleaning a shrimp      0
# 1     a lady is dressed in black and is carrying a w...      0
# 2             someone is putting ingredients into a wok      0
# 3     a man is rock climbing and a city and a bay ar...      0
# 4        there is no bunny playing with a stuffed bunny      1
# ...                                                 ...    ...
# 6689            a woman is standing near three children      1
# 6690  the man is not standing on a rocky mountain an...      1
# 6691                      the woman is removing make-up      1
# 6692  five kids are standing close together and one ...      0
# 6693                       a man is dancing on the road      1
#
# [6694 rows x 3 columns]

# %% [markdown]
# ### checking for null values

# %% [markdown]
# dataset.isnull().mean()

# %%
dataset['label'].value_counts()
# Out:
# label
# 0    4866
# 1    1828
# Name: count, dtype: int64

# %%
nltk.download('stopwords') # download stopwords in english from nltk library
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ahmad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
dataset['whole_sentence']=dataset['SENTENCE A']+ " " + dataset['SENTENCE B']

# %%
dataset['whole_sentence'].head()
# Out:
# 0    someone is dirtying an animal a woman is clean...
# 1    a woman in a black dress is pulling a cart and...
# 2    a person is cutting garlic into pieces with a ...
# 3    a woman is rock climbing pausing and calculati...
# 4    a rabbit is playing with a toy rabbit there is...
# Name: whole_sentence, dtype: object

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ahmad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# import these modules
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print("cleaning :", lemmatizer.lemmatize("saw"))
print("pulling :", lemmatizer.lemmatize("pulling"))

# a denotes adjective in "pos"
print("better :", lemmatizer.lemmatize("better", pos="a"))
# Out:
# cleaning : saw
# pulling : pulling
# better : good

# %%
import spacy 
nlp=spacy.load('en_core_web_sm')

# %% [markdown]
# ### if we lemmatize stopwords what they would be looklike

# %%
l=['no', 'nor', 'not', 'only', 'own', 'same',
'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven'
   , "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', 
   "weren't", 'won', "won't", 'wouldn', "wouldn"]
doc2=nlp(' '.join(l))
for token in doc2:
    print(f'{token.text} {token.lemma_}')
# Out:
# no no
# nor nor
# not not
# only only
# own own
# same same
# so so
# than than
# too too
# very very
# s s
# t t
# can can
# will will
# just just
# don don
# do do
# n't not
# should should
# should should
# 've 've
# now now
# d d
# ll ll
# m m
# o o
# re re
# ve ve
# y y
# ain ain
# aren aren
# are be
# n't not
# couldn couldn
# could could
# n't not
# didn didn
# did do
# n't not
# doesn doesn
# does do
# n't not
# hadn hadn
# had have
# n't not
# hasn hasn
# has have
# n't not
# haven haven
# have have
# n't not
# isn isn
# is be
# n't not
# ma ma
# mightn mightn
# might might
# n't not
# mustn mustn
# must must
# n't not
# needn needn
# need need
# n't not
# shan shan
# sha sha
# n't not
# shouldn shouldn
# should should
# n't not
# wasn wasn
# was be
# n't not
# weren weren
# were be
# n't not
# won win
# wo will
# n't not
# wouldn wouldn
# wouldn wouldn

# %% [markdown]
# ### stopwords of spacey library

# %%
nlp.Defaults.stop_words
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
stop_list= ['i','is','be','are','am','me','had', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
            'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself',
             'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who',
            'whom', 'this', 'that', 'these', 'those', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
            'while', 'of', 'at', 'by', 'for', 'with', 'about', 'through', 'during', 'to', 'from', 'further', 'then', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'other'
            , 'such',  'only', 'own', 'same', 'so','a','than', 'too', 'can', 'will', 'just', 'now',
           'because','become','becomes','will','with','within','without','whenever','whereafter','while','whole','whom','whose',
            'why','would','what','twelve','twenty','two','very','too','quite','rather','re','really','regarding','same','say','see','seem','seemed','seeming','seems','several','she','should','show','side','since','six','sixty','so','somehow','someone','something','somewhere','still','such','take','ten','than','that','the','their','them','themselves','then','thence','there','thereafter','thereby','therefore','therein','thereupon','these','they','third','this','those','though','three','through']

# %% [markdown]
# ### the reason i madeup my own stop words list is because in libraries , they consider the negative verbs as stopwords too so i should remove them

# %%
list1=[]
def lemmatize(text):
    text=nlp(text)
    l_list=[]
    for i in text:
        
        l_list.append(i.lemma_)
    stemmed_content=' '.join(l_list)
    return stemmed_content

# %%
dataset['whole_sentence1']=dataset['whole_sentence'].apply(lemmatize)
dataset.head()
# Out:
#                                           SENTENCE A
# 0                      someone is dirtying an animal  \
# 1  a woman in a black dress is pulling a cart and...
# 2  a person is cutting garlic into pieces with a ...
# 3  a woman is rock climbing pausing and calculati...
# 4              a rabbit is playing with a toy rabbit
#
#                                           SENTENCE B  label
# 0                       a woman is cleaning a shrimp      0  \
# 1  a lady is dressed in black and is carrying a w...      0
# 2          someone is putting ingredients into a wok      0
# 3  a man is rock climbing and a city and a bay ar...      0
# 4     there is no bunny playing with a stuffed bunny      1
#
#                                       whole_sentence
# 0  someone is dirtying an animal a woman is clean...  \
# 1  a woman in a black dress is pulling a cart and...
# 2  a person is cutting garlic into pieces with a ...
# 3  a woman is rock climbing pausing and calculati...
# 4  a rabbit is playing with a toy rabbit there is...
#
#                                      whole_sentence1
# 0  someone be dirty an animal a woman be clean a ...
# 1  a woman in a black dress be pull a cart and be...
# 2  a person be cut garlic into piece with a knife...
# 3  a woman be rock climb pausing and calculate th...
# 4  a rabbit be play with a toy rabbit there be no...

# %%
def stemming(content):
    stemmed_content=re.sub('[^a-zA-z.,]',' ',content)
    stemmed_content=stemmed_content.lower()
    stemmed_content=stemmed_content.split()
    stemmed_content=[word for word in stemmed_content if not word in stop_list]
    print(stemmed_content)
    stemmed_content=' '.join(stemmed_content)
    return stemmed_content

# %%
dataset['whole_sentence1']=dataset['whole_sentence1'].apply(stemming)

# %%
dataset
# Out:
#                                              SENTENCE A
# 0                         someone is dirtying an animal  \
# 1     a woman in a black dress is pulling a cart and...
# 2     a person is cutting garlic into pieces with a ...
# 3     a woman is rock climbing pausing and calculati...
# 4                 a rabbit is playing with a toy rabbit
# ...                                                 ...
# 6689     there is no woman standing near three children
# 6690  the man is standing on a rocky mountain and gr...
# 6691                    a woman is putting on eyeshadow
# 6692  five wooden stands are in front of each childs...
# 6693                there is no man dancing on the road
#
#                                              SENTENCE B  label
# 0                          a woman is cleaning a shrimp      0  \
# 1     a lady is dressed in black and is carrying a w...      0
# 2             someone is putting ingredients into a wok      0
# 3     a man is rock climbing and a city and a bay ar...      0
# 4        there is no bunny playing with a stuffed bunny      1
# ...                                                 ...    ...
# 6689            a woman is standing near three children      1
# 6690  the man is not standing on a rocky mountain an...      1
# 6691                      the woman is removing make-up      1
# 6692  five kids are standing close together and one ...      0
# 6693                       a man is dancing on the road      1
#
#                                          whole_sentence
# 0     someone is dirtying an animal a woman is clean...  \
# 1     a woman in a black dress is pulling a cart and...
# 2     a person is cutting garlic into pieces with a ...
# 3     a woman is rock climbing pausing and calculati...
# 4     a rabbit is playing with a toy rabbit there is...
# ...                                                 ...
# 6689  there is no woman standing near three children...
# 6690  the man is standing on a rocky mountain and gr...
# 6691  a woman is putting on eyeshadow the woman is r...
# 6692  five wooden stands are in front of each childs...
# 6693  there is no man dancing on the road a man is d...
#
#                                         whole_sentence1
# 0                       dirty animal woman clean shrimp
# 1     woman in black dress pull cart stand in front ...
# 2     person cut garlic into piece knife put ingredi...
# 3     woman rock climb pausing calculate route man r...
# 4      rabbit play toy rabbit no bunny play stuff bunny
# ...                                                 ...
# 6689   no woman stand near child woman stand near child
# 6690  man stand on rocky mountain gray cloud in back...
# 6691        woman put on eyeshadow woman remove make up
# 6692  five wooden stand in front child hut five kid ...
# 6693             no man dance on road man dance on road
#
# [6694 rows x 5 columns]

# %% [markdown]
# # *********************************************************************************************

# %%
type(dataset['whole_sentence'].values)
# Out:
# numpy.ndarray

# %%
x=dataset['whole_sentence1'].values
y=dataset['label'].values

# %% [markdown]
# ### vectorizing

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_df=0.80,min_df=2)
x = vectorizer.fit_transform(x).toarray()

# %%
vectorizer = TfidfVectorizer(max_df=0.75,min_df=3)
vectorizer.fit(x)
x=vectorizer.transform(x)
x.shape

# %%
x.shape
# Out:
# (6694, 1759)

# %% [markdown]
# ### because of having imbalanced dataset we should use tools to resample it in order to solve this problem

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x_train1, y_train1 = sm.fit_resample(x, y)

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
x_train1, y_train1 = oversample.fit_resample(x, y)

# %%
from imblearn.under_sampling import RandomUnderSampler
undersample = RandomUnderSampler(sampling_strategy='majority')
x_train1, y_train1 = undersample.fit_resample(x, y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_train1,y_train1,test_size=0.2)

# %%
x_train.shape

# %% [markdown]
# ### first model

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=400)
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=400)

# %%
from sklearn.metrics import f1_score,confusion_matrix
prediction=classifier.predict(x_test)
print(f'accuracy score: {round(f1_score(prediction,y_test),3)*100}')
print(confusion_matrix(prediction,y_test))
# Out:
# accuracy score: 95.0
# [[896  26]
#  [ 75 950]]

# %% [markdown]
# ### second model

# %%
from sklearn.naive_bayes import MultinomialNB
classifer=MultinomialNB()
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=400)

# %%
prediction=classifier.predict(x_test)
print(f'accuracy score: {round(f1_score(prediction,y_test),3)*100}')
print(confusion_matrix(prediction,y_test))
# Out:
# accuracy score: 94.8
# [[894  28]
#  [ 77 948]]

# %% [markdown]
# ### third model

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'gini')
classifier.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=classifier.predict(x_test)
print(f'accuracy score: {round(f1_score(prediction,y_test),3)*100}')
print(confusion_matrix(prediction,y_test))
# Out:
# accuracy score: 92.60000000000001
# [[843  25]
#  [128 951]]

# %% [markdown]
# ### fourth model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import f1_score,confusion_matrix
prediction=model.predict(x_test)
print(f'accuracy score: {round(f1_score(prediction,y_test),3)*100}')
print(confusion_matrix(prediction,y_test))
# Out:
# accuracy score: 86.3
# [[808 112]
#  [163 864]]

# %% [markdown]
# ### deep learning model

# %%
from keras.callbacks import EarlyStopping
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
import tensorflow as tf
model=tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=128,activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=32,activation='relu'))
model.add(tf.keras.layers.Dense(units=16,activation='relu'))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,batch_size=16,epochs=32,validation_data=(x_test, y_test))
# Out:
# Epoch 1/32
# 487/487 [==============================] - 3s 4ms/step - loss: 0.4505 - accuracy: 0.8054 - val_loss: 0.3457 - val_accuracy: 0.8618
# Epoch 2/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.2755 - accuracy: 0.8898 - val_loss: 0.2846 - val_accuracy: 0.8819
# Epoch 3/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.2005 - accuracy: 0.9164 - val_loss: 0.2730 - val_accuracy: 0.9004
# Epoch 4/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.1486 - accuracy: 0.9385 - val_loss: 0.2586 - val_accuracy: 0.9076
# Epoch 5/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.1133 - accuracy: 0.9575 - val_loss: 0.2712 - val_accuracy: 0.9111
# Epoch 6/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.0923 - accuracy: 0.9678 - val_loss: 0.2636 - val_accuracy: 0.9255
# Epoch 7/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0701 - accuracy: 0.9762 - val_loss: 0.2983 - val_accuracy: 0.9235
# Epoch 8/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.0625 - accuracy: 0.9776 - val_loss: 0.3091 - val_accuracy: 0.9281
# Epoch 9/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0474 - accuracy: 0.9834 - val_loss: 0.3308 - val_accuracy: 0.9240
# Epoch 10/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0457 - accuracy: 0.9850 - val_loss: 0.3606 - val_accuracy: 0.9276
# Epoch 11/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.0441 - accuracy: 0.9852 - val_loss: 0.3660 - val_accuracy: 0.9219
# Epoch 12/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.0397 - accuracy: 0.9863 - val_loss: 0.3826 - val_accuracy: 0.9199
# Epoch 13/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.0383 - accuracy: 0.9859 - val_loss: 0.3688 - val_accuracy: 0.9307
# Epoch 14/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0325 - accuracy: 0.9896 - val_loss: 0.3748 - val_accuracy: 0.9260
# Epoch 15/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0271 - accuracy: 0.9899 - val_loss: 0.4323 - val_accuracy: 0.9214
# Epoch 16/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0249 - accuracy: 0.9908 - val_loss: 0.4150 - val_accuracy: 0.9286
# Epoch 17/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0244 - accuracy: 0.9902 - val_loss: 0.4442 - val_accuracy: 0.9286
# Epoch 18/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0258 - accuracy: 0.9909 - val_loss: 0.4908 - val_accuracy: 0.9240
# Epoch 19/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0241 - accuracy: 0.9913 - val_loss: 0.4303 - val_accuracy: 0.9255
# Epoch 20/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0179 - accuracy: 0.9936 - val_loss: 0.4849 - val_accuracy: 0.9245
# Epoch 21/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0228 - accuracy: 0.9927 - val_loss: 0.4724 - val_accuracy: 0.9209
# Epoch 22/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0173 - accuracy: 0.9937 - val_loss: 0.4771 - val_accuracy: 0.9286
# Epoch 23/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0178 - accuracy: 0.9934 - val_loss: 0.5121 - val_accuracy: 0.9209
# Epoch 24/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0198 - accuracy: 0.9937 - val_loss: 0.4665 - val_accuracy: 0.9291
# Epoch 25/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0182 - accuracy: 0.9943 - val_loss: 0.5155 - val_accuracy: 0.9158
# Epoch 26/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.4847 - val_accuracy: 0.9199
# Epoch 27/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0141 - accuracy: 0.9955 - val_loss: 0.5031 - val_accuracy: 0.9260
# Epoch 28/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0147 - accuracy: 0.9950 - val_loss: 0.5237 - val_accuracy: 0.9317
# Epoch 29/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.5336 - val_accuracy: 0.9230
# Epoch 30/32
# 487/487 [==============================] - 2s 4ms/step - loss: 0.0149 - accuracy: 0.9954 - val_loss: 0.4897 - val_accuracy: 0.9255
# Epoch 31/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 0.5675 - val_accuracy: 0.9214
# Epoch 32/32
# 487/487 [==============================] - 2s 3ms/step - loss: 0.0105 - accuracy: 0.9969 - val_loss: 0.5739 - val_accuracy: 0.9188

# %%
from sklearn.metrics import f1_score,confusion_matrix
prediction=model.predict(x_test)
prediction = np.where(prediction > 0.5, 1, 0)
print(prediction)
print(f'accuracy score: {round(f1_score(prediction,y_test),3)*100}')
print(confusion_matrix(prediction,y_test))
# Out:
# 61/61 [==============================] - 0s 2ms/step
# [[0]
#  [0]
#  [0]
#  ...
#  [1]
#  [0]
#  [0]]
# accuracy score: 92.30000000000001
# [[847  34]
#  [124 942]]

# %% [markdown]
# ### last model

# %%
from xgboost import XGBClassifier

model = XGBClassifier().fit(x_train, y_train)

# predict
prediction = model.predict(x_test)

# accuracy score/

xgb_score = accuracy_score(prediction, y_test)

print('Accuracy score is:', xgb_score)
# Out:
# Accuracy score is: 0.9070364663585002

# %%
from sklearn.metrics import f1_score
prediction=model.predict(x_test)
print(f'accuracy score: {round(f1_score(prediction,y_test),3)*100}')
# Out:
# accuracy score: 91.0

# %% [markdown]
# # testing our model

# %%
import pandas as pd
test_dataset=pd.read_csv('C://Users//ahmad//OneDrive//Desktop//New folder (2)/test.csv')

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
# [744 rows x 2 columns]

# %%
test_dataset['whole_sentence']=test_dataset['SENTENCE A'] + ' '+ test_dataset['SENTENCE B']

# %%
test_dataset['whole_sentence'].head()
# Out:
# 0    a woman is peeling a potato a woman is not pee...
# 1    two boys on a couch are reading a book two boy...
# 2    the man on stage isnt singing into the microph...
# 3    tom is still in a deep coma tom is still in a ...
# 4    there is no dog turning on the grass and pursu...
# Name: whole_sentence, dtype: object

# %%
test_dataset['whole_sentence'].shape
# Out:
# (744,)

# %%
stop_list= ['i','is','be','are','am','me','had', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
            'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself',
             'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who',
            'whom', 'this', 'that', 'these', 'those', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
            'while', 'of', 'at', 'by', 'for', 'with', 'about', 'through', 'during', 'to', 'from', 'further', 'then', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'other'
            , 'such',  'only', 'own', 'same', 'so','a','than', 'too', 'can', 'will', 'just', 'now',
           'because','become','becomes','will','with','within','without','whenever','whereafter','while','whole','whom','whose',
            'why','would','what','twelve','twenty','two','very','too','quite','rather','re','really','regarding','same','say','see','seem','seemed','seeming','seems','several','she','should','show','side','since','six','sixty','so','somehow','someone','something','somewhere','still','such','take','ten','than','that','the','their','them','themselves','then','thence','there','thereafter','thereby','therefore','therein','thereupon','these','they','third','this','those','though','three','through']

# %%
def stemming(content):
    stemmed_content=re.sub('[^a-zA-z.,]',' ',content)
    stemmed_content=stemmed_content.lower()
    stemmed_content=stemmed_content.split()
    stemmed_content=[word for word in stemmed_content if not word in stop_list]
    print(stemmed_content)
    stemmed_content=' '.join(stemmed_content)
    return stemmed_content

# %%
list24=[]
def lemmatize(text):
    text=nlp(text)
    l_list=[]
    for i in text:
        
        l_list.append(i.lemma_)
    stemmed_content=' '.join(l_list)
    return stemmed_content

# %%
test_dataset['whole_sentence']=test_dataset['whole_sentence'].apply(lemmatize)

# %%
test_dataset['whole_sentence']=test_dataset['whole_sentence'].apply(stemming)

# %%
x=test_dataset['whole_sentence'].values
x.shape
# Out:
# (744,)

# %%
x=vectorizer.transform(x)

# %%
x.shape
# Out:
# (744, 1549)

# %%
prediction=model.predict(x)
prediction = np.where(prediction > 0.5, 1, 0)
prediction.flatten()
# Out:
# 210/210 [==============================] - 0s 1ms/step
# array([0, 0, 0, ..., 1, 0, 1])

# %%
prediction=classifier.predict(x)
prediction.flatten()

# %%
import csv
with open('C:/Users/ahmad/OneDrive/Desktop/output.csv','w') as myfile:
    dw=csv.DictWriter(myfile,fieldnames=['label'])
    dw.writeheader()
    for i in list(prediction.flatten()):
        myfile.write(str(i)+'\n')
myfile.close()

# %% [markdown]
# ### let's have a tricky solution

# %% [markdown]
# # using sentiment anlysis

# %%
import pandas as pd
import numpy as np
import re
import spacy

# %%
nlp=spacy.load('en_core_web_sm')

# %%
import pandas as pd
test_dataset=pd.read_csv('C://Users//ahmad//OneDrive//Desktop//New folder (2)/test.csv')

# %%
test_dataset['whole_sentence']=test_dataset['SENTENCE A'] + ' '+ test_dataset['SENTENCE B']

# %%
stop_list= ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such',  'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y']

# %%
def stemming(content):
    stemmed_content=re.sub('[^a-zA-z.,]',' ',content)
    stemmed_content=stemmed_content.lower()
    stemmed_content=stemmed_content.split()
    stemmed_content=[word for word in stemmed_content if not word in stop_list]
    stemmed_content=' '.join(stemmed_content)
    return stemmed_content

# %%
list24=[]
def lemmatize(text):
    text=nlp(text)
    l_list=[]
    for i in text:
        
        l_list.append(i.lemma_)
    stemmed_content=' '.join(l_list)
    return stemmed_content

# %%
test_dataset['whole_sentence']=test_dataset['whole_sentence'].apply(lemmatize)

# %%
test_dataset['whole_sentence']=test_dataset['whole_sentence'].apply(stemming)

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
# [744 rows x 3 columns]

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid=SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ahmad\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
test_dataset['scores']=test_dataset['whole_sentence'].apply(lambda review: sid.polarity_scores(review))

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...
# ..                                                 ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...
#
# [744 rows x 4 columns]

# %%
test_dataset['negativity']= test_dataset['scores'].apply(lambda x :x['neg'])

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores  negativity
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...       0.000
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...       0.155
# ..                                                 ...         ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...       0.180
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...       0.237
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...       0.255
#
# [744 rows x 5 columns]

# %%
words =["haven\'t", 'isn', "isn\'t", 'mightn', "mightn\'t", 'mustn', "mustn\'t", 'needn', "needn\'t", 'shan', "shan\'t", 'shouldn', "shouldn\'t", 'wasn', "wasn\'t", 'weren', 
   "weren\'t", 'won', "won\'t", 'wouldn', "wouldn",'not','no',"don\'t"]
words[0]
# Out:
# "haven't"

# %%
def check(text): 
    num1=0
    num2=1
    text=text.split()
    words =["haven\'t", 'isn', "isn\'t", 'mightn', "mightn\'t", 'mustn', "mustn\'t", 'needn', "needn\'t", 'shan', "shan\'t", 'shouldn', "shouldn\'t", 'wasn', "wasn\'t", 'weren', 
   "weren\'t", 'won', "won\'t", 'wouldn', "wouldn",'not','no',"don\'t"]
    boolean=2
    for word in words:
        if str(word) in  text: 
            boolean=1
            break
        else:
            boolean=2
            
    if boolean==1:
        return num2
    else:
        return num1

# %%
test_dataset['negativity2']=test_dataset['whole_sentence'].apply(check)

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores  negativity
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000  \
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...       0.000
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...       0.155
# ..                                                 ...         ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...       0.180
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...       0.237
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...       0.255
#
#      negativity2
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1
# ..           ...
# 739            0
# 740            1
# 741            1
# 742            0
# 743            0
#
# [744 rows x 6 columns]

# %%
def check2(x):
    x=float(x)
    num1=0
    num2=1
    if x>0:
        return num2
    else:
        return num1

# %%
test_dataset['negativity1']=test_dataset['negativity'].apply(check2)

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores  negativity
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000  \
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...       0.000
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...       0.155
# ..                                                 ...         ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...       0.180
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...       0.237
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...       0.255
#
#      negativity2  negativity1
# 0              1            0
# 1              0            0
# 2              1            0
# 3              0            0
# 4              1            1
# ..           ...          ...
# 739            0            0
# 740            1            1
# 741            1            1
# 742            0            0
# 743            0            1
#
# [744 rows x 7 columns]

# %%
test_dataset['negetivity3']=test_dataset['negativity1']+ test_dataset['negativity2']

# %%
def check3(x):
    num1=1
    num2=0
    if x>0:
        return num1
    else:
        return num2

# %%
test_dataset['negetivity3']=test_dataset['negetivity3'].apply(check3)

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores  negativity
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000  \
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...       0.000
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...       0.155
# ..                                                 ...         ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...       0.180
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...       0.237
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...       0.255
#
#      negativity2  negativity1  negetivity3
# 0              1            0            1
# 1              0            0            0
# 2              1            0            1
# 3              0            0            0
# 4              1            1            1
# ..           ...          ...          ...
# 739            0            0            0
# 740            1            1            1
# 741            1            1            1
# 742            0            0            0
# 743            0            1            1
#
# [744 rows x 8 columns]

# %%
test_dataset['compound']= test_dataset['scores'].apply(lambda x :x['compound'])

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores  negativity
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000  \
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...       0.000
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...       0.155
# ..                                                 ...         ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...       0.180
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...       0.237
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...       0.255
#
#      negativity2  negativity1  negetivity3  compound
# 0              1            0            1    0.0000
# 1              0            0            0    0.3400
# 2              1            0            1    0.0000
# 3              0            0            0    0.0000
# 4              1            1            1   -0.2960
# ..           ...          ...          ...       ...
# 739            0            0            0    0.0000
# 740            1            1            1   -0.2960
# 741            1            1            1    0.5859
# 742            0            0            0    0.0000
# 743            0            1            1   -0.5859
#
# [744 rows x 9 columns]

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores  negativity
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000  \
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...       0.000
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...       0.155
# ..                                                 ...         ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...       0.180
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...       0.237
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...       0.000
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...       0.255
#
#      negativity2  negativity1  negetivity3  compound
# 0              1            0            1    0.0000
# 1              0            0            0    0.3400
# 2              1            0            1    0.0000
# 3              0            0            0    0.0000
# 4              1            1            1   -0.2960
# ..           ...          ...          ...       ...
# 739            0            0            0    0.0000
# 740            1            1            1   -0.2960
# 741            1            1            1    0.5859
# 742            0            0            0    0.0000
# 743            0            1            1   -0.5859
#
# [744 rows x 9 columns]

# %%
test_dataset=test_dataset.drop(['negativity1','negativity2','negativity','compound'],axis=1)

# %%
test_dataset
# Out:
#                                             SENTENCE A
# 0                          a woman is peeling a potato  \
# 1               two boys on a couch are reading a book
# 2    the man on stage isnt singing into the microphone
# 3                          tom is still in a deep coma
# 4    there is no dog turning on the grass and pursu...
# ..                                                 ...
# 739  an asian woman in in the midst of many people ...
# 740  a man is rapidly chopping some mushrooms with ...
# 741  two girls are laughing and other girls are wat...
# 742  some ingredients are being mixed in a bowl by ...
# 743  a bike rider in a black and red uniform is sta...
#
#                                             SENTENCE B
# 0                      a woman is not peeling a potato  \
# 1          two boys on a couch are playing video games
# 2    a man in a suit is standing at a microphone an...
# 3                         tom is still in a light coma
# 4    a dog is turning on the grass and pursuing a f...
# ..                                                 ...
# 739      a girl with a black bag is on a crowded train
# 740  there is no man rapidly chopping some mushroom...
# 741  there is no girl laughing and there is no othe...
# 742     a woman is bowling two eggs to a break dancer
# 743  a black bike rider in a red bike uniform is st...
#
#                                         whole_sentence
# 0              woman peel potato woman not peel potato  \
# 1    two boy couch read book two boy couch play vid...
# 2    man stage not singe microphone man suit stand ...
# 3             tom still deep coma tom still light coma
# 4    no dog turn grass pursue fly ball dog turn gra...
# ..                                                 ...
# 739  asian woman midst many people carry black bag ...
# 740  man rapidly chop mushroom knife no man rapidly...
# 741  two girl laugh girl watch no girl laugh no gir...
# 742  ingredient mix bowl person woman bowl two egg ...
# 743  bike rider black red uniform stand dirt bike b...
#
#                                                 scores  negetivity3
# 0    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...            1
# 1    {'neg': 0.0, 'neu': 0.806, 'pos': 0.194, 'comp...            0
# 2    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...            1
# 3    {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...            0
# 4    {'neg': 0.155, 'neu': 0.845, 'pos': 0.0, 'comp...            1
# ..                                                 ...          ...
# 739  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...            0
# 740  {'neg': 0.18, 'neu': 0.82, 'pos': 0.0, 'compou...            1
# 741  {'neg': 0.237, 'neu': 0.376, 'pos': 0.387, 'co...            1
# 742  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...            0
# 743  {'neg': 0.255, 'neu': 0.745, 'pos': 0.0, 'comp...            1
#
# [744 rows x 5 columns]

# %%
len(list(s))
# Out:
# 744

# %%
import csv
with open('C:/Users/ahmad/OneDrive/Desktop/output.csv','w') as myfile:
    dw=csv.DictWriter(myfile,fieldnames=['label'])
    dw.writeheader()
    for i in list(s):
        myfile.write(str(i)+'\n')
myfile.close()
